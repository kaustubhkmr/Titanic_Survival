# %%
import pandas as pd
        # the following command is to load it from the web directly
    # iris = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')
iris = pd.read_csv('iris.data.txt')
print ('Type = \n', type(iris))
print ('\nHead(20) = \n',iris.head(20))
print ('\nTail(20) = \n',iris.tail(20))

print('\n')
iris.columns = ['a1', 'sw', 'p1', 'pw', 'flower-class']
print (iris.head())
print ('\n dtype = \n', iris.dtypes)
print ('\n Shape = \n',iris.shape)
print ('\n\n Describe = \n',iris.describe())
# Out:
# Type =
#  <class 'pandas.core.frame.DataFrame'>
#
# Head(20) =
#      5.1  3.5  1.4  0.2  Iris-setosa
# 0   4.9  3.0  1.4  0.2  Iris-setosa
# 1   4.7  3.2  1.3  0.2  Iris-setosa
# 2   4.6  3.1  1.5  0.2  Iris-setosa
# 3   5.0  3.6  1.4  0.2  Iris-setosa
# 4   5.4  3.9  1.7  0.4  Iris-setosa
# 5   4.6  3.4  1.4  0.3  Iris-setosa
# 6   5.0  3.4  1.5  0.2  Iris-setosa
# 7   4.4  2.9  1.4  0.2  Iris-setosa
# 8   4.9  3.1  1.5  0.1  Iris-setosa
# 9   5.4  3.7  1.5  0.2  Iris-setosa
# 10  4.8  3.4  1.6  0.2  Iris-setosa
# 11  4.8  3.0  1.4  0.1  Iris-setosa
# 12  4.3  3.0  1.1  0.1  Iris-setosa
# 13  5.8  4.0  1.2  0.2  Iris-setosa
# 14  5.7  4.4  1.5  0.4  Iris-setosa
# 15  5.4  3.9  1.3  0.4  Iris-setosa
# 16  5.1  3.5  1.4  0.3  Iris-setosa
# 17  5.7  3.8  1.7  0.3  Iris-setosa
# 18  5.1  3.8  1.5  0.3  Iris-setosa
# 19  5.4  3.4  1.7  0.2  Iris-setosa
#
# Tail(20) =
#       5.1  3.5  1.4  0.2     Iris-setosa
# 129  7.4  2.8  6.1  1.9  Iris-virginica
# ...

# %%
print (pd.isnull(iris))    # checks for every value is it is null
print (pd.isnull(iris).sum())    # it aggregates the boolean in a single column
# Out:
#         a1     sw     p1     pw  flower-class
# 0    False  False  False  False         False
# 1    False  False  False  False         False
# 2    False  False  False  False         False
# 3    False  False  False  False         False
# 4    False  False  False  False         False
# 5    False  False  False  False         False
# 6    False  False  False  False         False
# 7    False  False  False  False         False
# 8    False  False  False  False         False
# 9    False  False  False  False         False
# 10   False  False  False  False         False
# 11   False  False  False  False         False
# 12   False  False  False  False         False
# 13   False  False  False  False         False
# 14   False  False  False  False         False
# 15   False  False  False  False         False
# 16   False  False  False  False         False
# 17   False  False  False  False         False
# 18   False  False  False  False         False
# ...

# %%
iris.iloc[1:3, 1:3]    # it defines the no of rows and columns to display
# Out:
#     sw   p1
# 1  3.2  1.3
# 2  3.1  1.5

# %%
iris.sw    # iris.column_name
# Out:
# 0      3.0
# 1      3.2
# 2      3.1
# 3      3.6
# 4      3.9
# 5      3.4
# 6      3.4
# 7      2.9
# 8      3.1
# 9      3.7
# 10     3.4
# 11     3.0
# 12     3.0
# 13     4.0
# 14     4.4
# 15     3.9
# 16     3.5
# 17     3.8
# 18     3.8
# 19     3.4
# 20     3.7
# 21     3.6
# 22     3.3
# 23     3.4
# 24     3.0
# 25     3.4
# 26     3.5
# 27     3.4
# 28     3.2
# 29     3.1
#       ...
# 119    3.2
# 120    2.8
# 121    2.8
# 122    2.7
# 123    3.3
# 124    3.2
# 125    2.8
# 126    3.0
# 127    2.8
# 128    3.0
# 129    2.8
# 130    3.8
# 131    2.8
# 132    2.8
# 133    2.6
# 134    3.0
# 135    3.4
# 136    3.1
# 137    3.0
# 138    3.1
# 139    3.1
# 140    3.1
# 141    2.7
# 142    3.2
# 143    3.3
# 144    3.0
# 145    2.5
# 146    3.0
# 147    3.4
# 148    3.0
# Name: sw, Length: 149, dtype: float64

# %%
iris.sw.sum()
# Out:
# 454.60000000000014

# %%
import numpy as np
iris.iloc[1:3, 1:2] = np.nan
iris.head()
# Out:
#     a1   sw   p1   pw flower-class
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  NaN  1.3  0.2  Iris-setosa
# 2  4.6  NaN  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
pd.isnull(iris)
# Out:
#         a1     sw     p1     pw  flower-class
# 0    False  False  False  False         False
# 1    False   True  False  False         False
# 2    False   True  False  False         False
# 3    False  False  False  False         False
# 4    False  False  False  False         False
# 5    False  False  False  False         False
# 6    False  False  False  False         False
# 7    False  False  False  False         False
# 8    False  False  False  False         False
# 9    False  False  False  False         False
# 10   False  False  False  False         False
# 11   False  False  False  False         False
# 12   False  False  False  False         False
# 13   False  False  False  False         False
# 14   False  False  False  False         False
# 15   False  False  False  False         False
# 16   False  False  False  False         False
# 17   False  False  False  False         False
# 18   False  False  False  False         False
# ...

# %%
iris.sw.fillna(1, inplace = True)    # you can fill an item in place of NaN in the column sw using fillna and type what you have to enter
    # inplace = true, make changes to the same matrix
    # inplace = false makes changes to a separate matrix which has been copied from the original matrix
iris.head()
# Out:
#     a1   sw   p1   pw flower-class
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  1.0  1.3  0.2  Iris-setosa
# 2  4.6  1.0  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
y = iris['flower-class']
    # now you have to delete it from the main data set x
del iris['flower-class']
print (iris.head())
y
# Out:
#     a1   sw   p1   pw
# 0  4.9  3.0  1.4  0.2
# 1  4.7  1.0  1.3  0.2
# 2  4.6  1.0  1.5  0.2
# 3  5.0  3.6  1.4  0.2
# 4  5.4  3.9  1.7  0.4
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
# 5         Iris-setosa
# 6         Iris-setosa
# 7         Iris-setosa
# 8         Iris-setosa
# 9         Iris-setosa
# 10        Iris-setosa
# 11        Iris-setosa
# 12        Iris-setosa
# 13        Iris-setosa
# 14        Iris-setosa
# 15        Iris-setosa
# 16        Iris-setosa
# 17        Iris-setosa
# 18        Iris-setosa
# 19        Iris-setosa
# 20        Iris-setosa
# 21        Iris-setosa
# 22        Iris-setosa
# 23        Iris-setosa
# 24        Iris-setosa
# 25        Iris-setosa
# 26        Iris-setosa
# 27        Iris-setosa
# 28        Iris-setosa
# 29        Iris-setosa
#             ...
# 119    Iris-virginica
# 120    Iris-virginica
# 121    Iris-virginica
# 122    Iris-virginica
# ...

# %%
iris.iloc[1:3, 1:2] = np.nan
print (iris.head())
# Out:
#     a1   sw   p1   pw
# 0  4.9  3.0  1.4  0.2
# 1  4.7  NaN  1.3  0.2
# 2  4.6  NaN  1.5  0.2
# 3  5.0  3.6  1.4  0.2
# 4  5.4  3.9  1.7  0.4

# %%
iris.dropna(inplace = True)    # it removes the rows having NaN as values, here it romoves complete rows 1 and 2
iris.head()
# Out:
#     a1   sw   p1   pw
# 0  4.9  3.0  1.4  0.2
# 3  5.0  3.6  1.4  0.2
# 4  5.4  3.9  1.7  0.4
# 5  4.6  3.4  1.4  0.3
# 6  5.0  3.4  1.5  0.2

# %%
    # if inplace is false it returns a temp matrix, eg
a = iris.reset_index()
print (a)    # as shown here if Drop is False a new column is created with new indices, but the original one doesn't change and is added as a feature, as shown in the output

iris.reset_index(drop = True, inplace = True)    # by default inplace is false, and it resets the index
iris.head()
# Out:
#      index   a1   sw   p1   pw
# 0        0  4.9  3.0  1.4  0.2
# 1        3  5.0  3.6  1.4  0.2
# 2        4  5.4  3.9  1.7  0.4
# 3        5  4.6  3.4  1.4  0.3
# 4        6  5.0  3.4  1.5  0.2
# 5        7  4.4  2.9  1.4  0.2
# 6        8  4.9  3.1  1.5  0.1
# 7        9  5.4  3.7  1.5  0.2
# 8       10  4.8  3.4  1.6  0.2
# 9       11  4.8  3.0  1.4  0.1
# 10      12  4.3  3.0  1.1  0.1
# 11      13  5.8  4.0  1.2  0.2
# 12      14  5.7  4.4  1.5  0.4
# 13      15  5.4  3.9  1.3  0.4
# 14      16  5.1  3.5  1.4  0.3
# 15      17  5.7  3.8  1.7  0.3
# 16      18  5.1  3.8  1.5  0.3
# 17      19  5.4  3.4  1.7  0.2
# 18      20  5.1  3.7  1.5  0.4
# 19      21  4.6  3.6  1.0  0.2
# 20      22  5.1  3.3  1.7  0.5
# 21      23  4.8  3.4  1.9  0.2
# 22      24  5.0  3.0  1.6  0.2
# 23      25  5.0  3.4  1.6  0.4
# 24      26  5.2  3.5  1.5  0.2
# 25      27  5.2  3.4  1.4  0.2
# 26      28  4.7  3.2  1.6  0.2
# 27      29  4.8  3.1  1.6  0.2
# 28      30  5.4  3.4  1.5  0.4
# ...
